# %%
import soundfile as sf

# %%
import os
if os.path.basename(os.getcwd()) != 'biometria2':
    os.chdir(os.path.dirname(os.getcwd()))

# %%
data, samplerate = sf.read('data/audio/id12707/0kZhP6nSEzk/00000.wav')

# %%
samplerate
# Out:
# 16000

# %%
data.shape
# Out:
# (42240, 2)

# %%
data
# Out:
# array([[-0.00057983, -0.00036621],
#        [ 0.00039673,  0.00100708],
#        [-0.00054932,  0.00012207],
#        ...,
#        [ 0.04031372,  0.03250122],
#        [ 0.01931763,  0.03619385],
#        [-0.02069092, -0.01416016]])

# %%
import matplotlib.pyplot as plt

plt.scatter(data[:, 0], data[:, 1])
